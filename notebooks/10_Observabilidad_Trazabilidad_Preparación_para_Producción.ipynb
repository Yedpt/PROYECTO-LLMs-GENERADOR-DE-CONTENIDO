# %% [markdown]
# 🧠 CONCEPTO CLAVE: OBSERVABILIDAD
# ❌ Sistema sin observabilidad
#
# “No sé qué modelo respondió”
#
# “No sé qué estrategia se usó”
#
# “No sé por qué falló”
#
# ✅ Sistema observable
#
# Logs claros
#
# Trazabilidad por request
#
# Métricas básicas
#
# Preparado para herramientas como LangSmith

# %% [markdown]
# # Notebook 10 – Observabilidad y Trazabilidad
#
# Objetivo:
# Añadir logs estructurados y trazabilidad a todo el flujo de generación
# para entender, auditar y mejorar el sistema.

# %% [markdown]
# 🟩 CELDA 2 — ESTRATEGIA DE LOGS (TEORÍA)
# Qué vamos a loggear:
#
# 1️⃣ Pregunta del usuario
# 2️⃣ Estrategia usada (rag / graph / multiagent)
# 3️⃣ Score del juez
# 4️⃣ Número de reintentos
# 5️⃣ Tiempo de ejecución
#
# 👉 Nada de logs caóticos
# 👉 Logs estructurados
